# %% [markdown]
# <a href="https://colab.research.google.com/github/smdr111/data_preparation/blob/main/03_DATAWRANGLE_06_MissingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 3-MODUL. MA’LUMOTLARGA ISHLOV BERISH
#
# ### 3.2 Ma'lumotlarni tozalash va tayyorlash
#
# ## Ma'lumotlarni to'ldirish

# %% [markdown]
# Agar imkoni bo'lsa mavjud bo'lmagan qiymatlarni to'ldirish tavsiya qilinadi. Buning uchun `.fillna()` metodiga murojaat qilamiz.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %% [markdown]
# #### 1-usul. Barcha `NaN` larga standart qiymat berish
# **Bu (va boshqa) usuldan ko'r-ko'rona emas, mantiqan to'g'ri kelgandagina foydalaniladi.** Avvalgi darsimizdagi misolga qaytadigan bo'lsak, turmush qurmagan odamning nikohdan o'tgan sanasi bo'lmagan vaqtda, bunday qiymatlarni 0 bilan to'ldirib ketish mumkin.
#
# **Xato ma'lumotlar bilan to'ldirilgan jadval kelgusida Sun'iy Intellekt dasturingizning xato ishlashiga sabab bo'ladi.**
#
# Quyidagi misolda barcha `NaN` qiymatlarni 0 bilan almashtiramiz (garchi bunday qilish tavsiya qilinmasada).

# %%
df.fillna(0)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         0.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         0.0   171.7           0
# 86      volkswagen        sedan        97.3     0.0         ohc
# 87           volvo        sedan       104.3   188.8           0
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         0.0             21.0  13495.0
# ...

# %% [markdown]
# Agar har bir ustun uchun alohida standart qiymat bermoqchi bo'lsangiz, bir nechta qiymatni lug'at (ustun nomi: qiymat) kor'inishida  bershingiz mumkin.
#
# Quyidagi misolda `wheel-base` va `horsepower` ustunlari uchun alohida standart qiymatlar beramiz.

# %%
df.fillna({'wheel-base':90, 'horsepower':100})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        90.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        90.0   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       100.0             21.0  13495.0
# ...

# %% [markdown]
# `method='ffill'` parametri yordamida `NaN` qiymatlarni avvalgi qataordagi qiymatlar bilan to'ldirishimiz mumkin. Agar jadvalga ahamiyat bersak, ba'zi qavtolar qayta-qayta takrorlangan (narxi turlicha xolos). Demak bir avto haqidagi ma'lumotni o'xshash avto ma'lumotidan olishimiz mantiqan to'g'ri.

# %%
df[df.company=='audi']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 3        audi      sedan        99.8   176.6         ohc             four
# 4        audi      sedan        99.4   176.6         ohc             five
# 5        audi      sedan        99.8   177.3         ohc             five
# 6        audi      wagon       105.8   192.7         ohc             five
#
#        horsepower  average-mileage    price
# index
# 3           102.0             24.0  13950.0
# 4             NaN              NaN  17450.0
# 5           110.0             19.0  15250.0
# 6           110.0             19.0  18920.0

# %%
df[df.company=='audi'].fillna(method='ffill')
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 3        audi      sedan        99.8   176.6         ohc             four
# 4        audi      sedan        99.4   176.6         ohc             five
# 5        audi      sedan        99.8   177.3         ohc             five
# 6        audi      wagon       105.8   192.7         ohc             five
#
#        horsepower  average-mileage    price
# index
# 3           102.0             24.0  13950.0
# 4           102.0             24.0  17450.0
# 5           110.0             19.0  15250.0
# 6           110.0             19.0  18920.0

# %% [markdown]
# `method='bfill'` yordamida esa ekasincha, `NaN` qiymatni o'zidan keyingi qiymat bilan to'ldirib ketasiz.

# %%
df[df.company=='toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback         NaN   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         NaN             four
# 68     toyota  hatchback         NaN   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7     NaN         NaN             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67            NaN             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71            NaN             27.0   8778.0
# 79          156.0              NaN  15750.0

# %%
df[df.company=='toyota'].fillna(method='bfill')
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %% [markdown]
# Darvoqe, o'zgarishlarni asl DF da saqlab qolish uchun quyidagi usuldan foydalanish mumkin:

# %%
df[df.company=='toyota']=df[df.company=='toyota'].fillna(method='bfill')

# %%
df[df.company=='toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %% [markdown]
# `limit` parametri yordamida aynan nechta `NaN` qiymatlar ketma-ketligini to'ldirishni ham ko'rsatish mumkin. Tasavvur qiling, biror qatorda 10-20 ta qator qiymatlar yo'q shunday holatda bularning hammasini emas, boshida 2-3tasini avvalgi qator bilan to'ldirish talab qilinda `df.fillna(method='ffill', limit=2)` deb ko'rsatasiz.

# %% [markdown]
# Bo'sh qiymatlarni to'ldirishning yana bir usuli ustun uchun o'rta qiymatni olish. Quyidagi misolda `hatchback` turidagi moshinalar uchun mavjud bo'lmagan qiymatlarni o'rta qiymat bilan to'ldiramiz.

# %%
dfh = df[df['body-style']=='hatchback']
dfh
# Out:
#            company body-style  wheel-base  length engine-type  \
# index
# 2      alfa-romero  hatchback        94.5   171.2        ohcv
# 16       chevrolet  hatchback        88.4   141.1           l
# 17       chevrolet  hatchback        94.5   155.9         ohc
# 19           dodge  hatchback        93.7   157.3         ohc
# 20           dodge  hatchback        93.7     NaN         ohc
# 36           mazda  hatchback        93.1   159.1         NaN
# 37           mazda  hatchback        93.1   159.1         ohc
# 38           mazda  hatchback        93.1   159.1         ohc
# 39           mazda  hatchback         NaN     NaN         NaN
# 49      mitsubishi  hatchback         NaN   157.3         ohc
# 50      mitsubishi  hatchback        93.7     NaN         NaN
# 63         porsche  hatchback        98.4   175.7       dohcv
# 66          toyota  hatchback        95.7   158.7         ohc
# 67          toyota  hatchback        95.7   158.7         ohc
# ...

# %%
dfh.fillna(dfh.mean())
# Out:
#            company body-style  wheel-base   length engine-type  \
# index
# 2      alfa-romero  hatchback        94.5  171.200        ohcv
# 16       chevrolet  hatchback        88.4  141.100           l
# 17       chevrolet  hatchback        94.5  155.900         ohc
# 19           dodge  hatchback        93.7  157.300         ohc
# 20           dodge  hatchback        93.7  159.325         ohc
# 36           mazda  hatchback        93.1  159.100         NaN
# 37           mazda  hatchback        93.1  159.100         ohc
# 38           mazda  hatchback        93.1  159.100         ohc
# 39           mazda  hatchback        94.1  159.325         NaN
# 49      mitsubishi  hatchback        94.1  157.300         ohc
# 50      mitsubishi  hatchback        93.7  159.325         NaN
# 63         porsche  hatchback        98.4  175.700       dohcv
# 66          toyota  hatchback        95.7  158.700         ohc
# 67          toyota  hatchback        95.7  158.700         ohc
# ...

# %%
df.fillna({'horsepower':np.mean(df['horsepower']), "wheel-base":np.mean(df['wheel-base'])})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000   168.8        dohc
# 1      alfa-romero  convertible   99.072917   168.8        dohc
# 2      alfa-romero    hatchback   94.500000   171.2        ohcv
# 3             audi        sedan   99.800000   176.6         ohc
# 4             audi        sedan   99.400000   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan   97.300000   171.7         ohc
# 82      volkswagen        sedan   99.072917   171.7         NaN
# 86      volkswagen        sedan   97.300000     NaN         ohc
# 87           volvo        sedan  104.300000   188.8         NaN
# 88           volvo        wagon  104.300000   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four  108.297872             21.0  13495.0
# ...
