# %% [markdown]
# <a href="https://colab.research.google.com/github/smdr111/data_preparation/blob/main/03_DATAWRANGLE_10_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 3-MODUL. MA’LUMOTLARGA ISHLOV BERISH
#
# ### 3.2 Ma'lumotlarni tozalash va tayyorlash
#
# ## Boshqa foydali funksiyalar
#
# ### No-odatiy qiymatlarni topish

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/MOCK_USER_DATA.csv", index_col=0)
df.head()
# Out:
#    first_name   last_name                           email       gender   age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3      Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48

# %% [markdown]
# Yuqoridagi jadvlada odamlarning yoshi jamlangan. Keling jadval haqida qisqa ma'lumot olamiz:

# %%
df.describe()
# Out:
#                age
# count   100.000000
# mean    145.660000
# std     565.631411
# min     -85.000000
# 25%      22.750000
# 50%      53.500000
# 75%      84.250000
# max    4444.000000

# %% [markdown]
# Nimadur xato: `max` yosh `4444` deb ko'rsatayapti, tabiiyku bunday bo'lishi mumkin emas. `min` da ham manfiy qiymat ko'rishimiz mumkin, bu ham xato. Demak jadvalimizda noto'g'ri qiymatlar ham kirib qolgan.
#
# Keling, boshlanishiga katta qiymatlarni filtrlab olamiz, yaqin tarixda odam yoshi maksimum `123` dan oshmagnini bilgan holda, keling shu qiymatdan katta qatorlarni topamiz:

# %%
df[df.age>123]
# Out:
#     first_name  last_name                           email       gender   age
# id
# 3       Lilith   Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 39      Godard      Miere               gmiere12@1688.com   Polygender  3434
# 47       Cleve  Sparshatt      csparshatt1a@economist.com  Genderfluid   333
# 49       Trace   Stockney          tstockney1c@flavors.me       Female   344
# 65      Eloise    Snoddon    esnoddon1s@elegantthemes.com  Genderfluid   332
# 80       Gabie     Rothon              grothon27@ehow.com  Genderqueer  4444
# 100      Mable    Toffano          mtoffano2r@myspace.com     Bigender   233

# %% [markdown]
# Qatorlarning indeksini ham ajratib olishimiz mumkin:

# %%
idx = df[df.age>123].index
idx
# Out:
# Int64Index([3, 39, 47, 49, 65, 80, 100], dtype='int64', name='id')

# %% [markdown]
# Manfiy qiymatlarni ham yuqoridagi usul bilan filtrlab olishimiz mumkin:

# %%
df[df.age<0]
# Out:
#    first_name  last_name                           email       gender  age
# id
# 11     Elijah      Heine                eheinea@imdb.com     Bigender  -85
# 19      Luisa  Bradborne            lbradbornei@fema.gov       Female  -75
# 21      Levin     Worner                lwornerk@ihg.com  Genderqueer  -43
# 33   Ebenezer    Greeves           egreevesw@myspace.com         Male  -26
# 38       Hana   Langwade  hlangwade11@washingtonpost.com  Genderqueer  -42
# 90  Zachariah      Meins            zmeins2h@weather.com         Male  -69

# %% [markdown]
# Ikki filtrni jamlab yozish ham mumkin:

# %%
df[(df.age>123) | (df.age<0)]
# Out:
#     first_name  last_name                           email       gender   age
# id
# 3       Lilith   Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 11      Elijah      Heine                eheinea@imdb.com     Bigender   -85
# 19       Luisa  Bradborne            lbradbornei@fema.gov       Female   -75
# 21       Levin     Worner                lwornerk@ihg.com  Genderqueer   -43
# 33    Ebenezer    Greeves           egreevesw@myspace.com         Male   -26
# 38        Hana   Langwade  hlangwade11@washingtonpost.com  Genderqueer   -42
# 39      Godard      Miere               gmiere12@1688.com   Polygender  3434
# 47       Cleve  Sparshatt      csparshatt1a@economist.com  Genderfluid   333
# 49       Trace   Stockney          tstockney1c@flavors.me       Female   344
# 65      Eloise    Snoddon    esnoddon1s@elegantthemes.com  Genderfluid   332
# 80       Gabie     Rothon              grothon27@ehow.com  Genderqueer  4444
# ...

# %% [markdown]
# Qatorlar bilan qanday yo'l tutish sizga bog'liq. Manfiy qiymatlarni musbatga o'tkazishimiz mumkin, buning uchun `numpy` dagi `abs` funksiyasini qo'llaymiz:

# %%
df['age'] = df['age'].apply(np.abs)
df.head(15)
# Out:
#    first_name   last_name                           email       gender   age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3      Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48
# 6       Glynn      Ebbing          gebbing5@rakuten.co.jp  Genderfluid    77
# 7       Wendy     Popland                wpopland6@cbc.ca  Genderfluid    67
# 8         Nye   Anthiftle        nanthiftle7@examiner.com      Agender    99
# 9         Der      Neames        dneames8@ycombinator.com     Bigender    77
# 10      David    Meredyth      dmeredyth9@telegraph.co.uk       Female    68
# 11     Elijah       Heine                eheinea@imdb.com     Bigender    85
# ...

# %% [markdown]
# Katta qiymatlarni tashlab yuboramiz:

# %%
idx = df[df.age>123].index
df.drop(index=idx, inplace=True)
df.describe()
# Out:
#               age
# count   93.000000
# mean    52.612903
# std     29.978265
# min      1.000000
# 25%     29.000000
# 50%     52.000000
# 75%     77.000000
# max    100.000000

# %% [markdown]
# Ko'rib turganingizdek, jadval qiymatlari normal holatga qaytdi.
#
# Jadvlada yana bir e'tiborimni tortgna jihati, jinslar faqatgina erkak (`Male`) va ayol (`Female`) emas.

# %%
df.gender.value_counts()
# Out:
# Male           21
# Bigender       12
# Genderfluid    11
# Female         11
# Non-binary     10
# Genderqueer    10
# Polygender      9
# Agender         9
# Name: gender, dtype: int64

# %% [markdown]
# Agar bu sizning keyingi hisoblaringizga ta'sir o'tkazadi desangiz, bu qiymatlarni ham filtrlab olishingiz mumkin:

# %%
df[df['gender'].isin(['Male','Female'])]
# Out:
#    first_name     last_name                         email  gender  age
# id
# 2     Pietrek       Scanlin        pscanlin1@yolasite.com    Male   91
# 5    Mohammed    Habbershon  mhabbershon4@sourceforge.net  Female   48
# 10      David      Meredyth    dmeredyth9@telegraph.co.uk  Female   68
# 12  Raffaello     Firminger     rfirmingerb@bloomberg.com  Female   74
# 17      Byram   Martynikhin     bmartynikhing@jiathis.com    Male   40
# 19      Luisa     Bradborne          lbradbornei@fema.gov  Female   75
# 22        Ray         Padly           rpadlyl@twitpic.com    Male   85
# 26   Ephrayim    Westmacott         ewestmacottp@ning.com    Male   77
# 29      Biron      Acklands        backlandss@comsenz.com    Male   13
# 33   Ebenezer       Greeves         egreevesw@myspace.com    Male   26
# 34     Brooks          Vose             bvosex@amazon.com  Female   34
# 36        Axe       Arundel           aarundelz@yahoo.com  Female   14
# ...

# %% [markdown]
# ### Jadvlani aralashtirib tashlash
#
# Ba'zida, tadqiqod uchun jadvaldagi qiymatlar o'rnini aralashtirib tashlash talab qilinishi mumkin. Misol uchun, sizda ma'lumotlar ma'lum bir tartibda turibdi, lekin siz ma'lumotlarni tasodifiy tartibda chiqarmoqchiisiz, buning uchun `numpy` kutubxonasining `random` modulidagi `permutation` funksiyasiga murojaat qilamiz.
#
# Bizda quyidagi jadval bor:

# %%
df.head()
# Out:
#    first_name   last_name                         email       gender  age
# id
# 1     Dorothy     Verryan             dverryan0@who.int   Non-binary    1
# 2     Pietrek     Scanlin        pscanlin1@yolasite.com         Male   91
# 4        Knox  Cunningham  kcunningham3@yellowpages.com  Genderfluid    6
# 5    Mohammed  Habbershon  mhabbershon4@sourceforge.net       Female   48
# 6       Glynn      Ebbing        gebbing5@rakuten.co.jp  Genderfluid   77

# %% [markdown]
# Keling, jadval uzunligini topaylik:

# %%
len(df)
# Out:
# 93

# %% [markdown]
# Jadvalimizda 93 ta qator mavjud, biz 1-93 gacha sonlarni tasodifiy tartibda saqlovchi ro'yxat yaratamiz:

# %%
randlist = np.random.permutation(93)
randlist
# Out:
# array([72, 74,  4, 86, 84, 24, 71,  8, 91, 87,  6, 56, 19, 40,  9,  5, 13,
#        25, 55, 47, 58,  3, 11, 80, 38, 66, 23, 70, 79, 16, 22, 68, 29, 35,
#        21, 46,  1, 48, 52, 59, 53, 18, 67, 78, 30, 81, 83, 15,  0, 20, 65,
#        82, 64, 33, 62, 26, 61, 34, 31, 90, 57, 45, 41, 89, 28, 27, 12, 39,
#        36, 92, 77, 73, 54, 42, 85, 10, 14,  2, 51, 32, 37,  7, 69, 50, 75,
#        49, 17, 60, 63, 88, 43, 76, 44])

# %% [markdown]
# Navbat, `df` ni yuqoridagi tasodifiy tartibda tahlash, buning uchun `.take()` meotidga murojaat qilamiz

# %%
df.take(randlist)
# Out:
#    first_name     last_name                          email       gender  age
# id
# 78      Richy    Cornilleau           rcornilleau25@nhs.uk     Bigender   88
# 81       Alex         Darth     adarth28@ezinearticles.com       Female   98
# 6       Glynn        Ebbing         gebbing5@rakuten.co.jp  Genderfluid   77
# 93    Fairfax        Juleff             fjuleff2k@narod.ru   Polygender   84
# 91      Judas        Maffin          jmaffin2i@dropbox.com         Male    3
# ..        ...           ...                            ...          ...  ...
# 69      Ruthy       Bessett       rbessett1w@google.com.hk  Genderqueer    7
# 95      Byron    Whittleton  bwhittleton2m@theatlantic.com   Non-binary    2
# 46     Alvira  Stollsteiner      astollsteiner19@mysql.com         Male   66
# 83      Randy      Bauldrey           rbauldrey2a@jugem.jp     Bigender   81
# 48  Sutherlan        Duigan              sduigan1b@ask.com   Non-binary   27
#
# [93 rows x 5 columns]

# %% [markdown]
# Marhamat, jadvalimiz tasodifiy tartibda tahlandi.

# %% [markdown]
# ### Jadvladan  tasodifiy qiymatlarni chiqarib olish.
# Buning uchun bizga avvaldan tanish .sample() metodiga murojaat qilamiz va aynan nechta qiymat kerak ekanini ham ko'rsatamiz.
#
# Bunda tasodifiy qatorlar **takrorlanmagan** holda chiqadi.

# %%
df.sample(5)
# Out:
#    first_name   last_name                         email      gender  age
# id
# 64      Carla      Rumney           crumney1r@weibo.com  Polygender   56
# 44     Marice   Champneys    mchampneys17@bigcartel.com    Bigender   49
# 74      Curry  Smalecombe  csmalecombe21@washington.edu        Male   69
# 82     Wanids    Sifflett        wsifflett29@taobao.com  Polygender   20
# 66     Alejoa  Abrahamoff         aabrahamoff1t@com.com  Polygender   28

# %% [markdown]
# Agar qatorlar takrorlanishini istasangiz, `replace=True` parametrini ko'rsatasiz:

# %%
df.sample(10, replace=True)
# Out:
#    first_name last_name                        email       gender  age
# id
# 99  Desdemona   Jurasek     djurasek2q@aboutads.info  Genderfluid   46
# 90  Zachariah     Meins         zmeins2h@weather.com         Male   69
# 52     Tillie  Winslett  twinslett1f@theatlantic.com   Non-binary   90
# 9         Der    Neames     dneames8@ycombinator.com     Bigender   77
# 70      Ambur    Aickin          aaickin1x@about.com         Male   60
# 14    Mariana   Shevels            mshevelsd@msn.com      Agender   60
# 14    Mariana   Shevels            mshevelsd@msn.com      Agender   60
# 61       Page   Merrell    pmerrell1o@slideshare.net         Male    1
# 94     Sheree    Cockin    scockin2l@accuweather.com       Female   94
# 85       Dido    Megany         dmegany2c@unesco.org   Non-binary   65

# %% [markdown]
# Ahamiyat bering, `14` indeks ikki marta chiqdi.
